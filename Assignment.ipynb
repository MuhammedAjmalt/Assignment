# %% [markdown]
# # Read the data set to the python environment

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
data = pd.read_excel(r'C:\Users\user\Downloads/iris.xls')
print(data)
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # Columns in datasets

# %%
data1=list(data.columns.values)

# %%
print(data1)
# Out:
# ['SL', 'SW', 'PL', 'PW', 'Classification']

# %% [markdown]
# # Mean of each column in dataset

# %%
data3=data.mean()

# %%
print(data3)
# Out:
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %% [markdown]
# # Null values present in the datasets

# %%
data4=data.isnull()

# %%
print(data4)
# Out:
#         SL     SW     PL     PW  Classification
# 0    False  False  False  False           False
# 1    False  False  False  False           False
# 2    False  False  False  False           False
# 3    False  False  False  False           False
# 4    False  False  False  False           False
# ..     ...    ...    ...    ...             ...
# 145  False  False  False  False           False
# 146  False  False  False  False           False
# 147  False  False  False  False           False
# 148  False  False  False  False           False
# 149  False  False  False  False           False
#
# [150 rows x 5 columns]

# %% [markdown]
# # Visualization using datasets

# %%
plt.plot(data['Classification'],data['SL'])
plt.title('flower data')
plt.xlabel('classification of iris')
plt.ylabel('sepal length')
# Out:
# Text(0, 0.5, 'sepal length')

# %%
s=data[[ 'SL','SW','PL','PW','Classification']]
sns.pairplot(s)
# Out:
# Text(0.5, 1.0, 'iris classification')

# %%
sns.countplot(data['SW'])
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='SW', ylabel='count'>

# %%
sns.heatmap(s.corr(), annot=True)
# Out:
# <AxesSubplot:>
